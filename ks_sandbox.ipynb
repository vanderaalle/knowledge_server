# %% [markdown]
# # Knowledge Server Notebook: Sandbox. Modify with no fear
# Interface for indexing PDFs and querying the knowledge base via Ollama + Qdrant.

# %%
import os

# Environment variables — must be set before importing server
os.environ['OLLAMA_MODEL']    = 'mxbai-embed-large'
os.environ['QDRANT_HOST']     = 'localhost'
os.environ['QDRANT_PORT']     = '6333'
os.environ['COLLECTION_NAME'] = 'pdf_library'
os.environ['TESSERACT_CMD']   = '/usr/bin/tesseract'
os.environ['POPPLER_PATH']    = '/usr/bin'

# %%
import sys
sys.path.insert(0, '.')

import server
print('Server module loaded OK')
# Out:
# Server module loaded OK

# %% [markdown]
# ## Index a PDF library
# Point `PDF_DIR` to the folder containing your PDFs. Run once (or re-run to update).

# %%
# ⚠️  WIPE the collection — run this ONLY before a full re-index
# Deletes all vectors. Cannot be undone.
from qdrant_client import QdrantClient
_client = QdrantClient('localhost', port=6333)
_client.delete_collection('pdf_library')
print('Collection deleted. Ready to re-index.')
# Out:
# Collection deleted. Ready to re-index.

# %%
PDF_DIR = "/home/andrea/Books"  # <-- change this

try:
    result = server.index_library(PDF_DIR)
    print(result)
except TypeError:
    # Function may be async
    import asyncio
    result = asyncio.run(server.index_library(PDF_DIR))
    print(result)

# %% [markdown]
# ## Query the library

# %%
QUERY = 'andrea valle'  # <-- change this
N_RESULTS = 5

try:
    results = server.query_library(QUERY, n_results=N_RESULTS)
except TypeError:
    import asyncio
    results = asyncio.run(server.query_library(QUERY, n_results=N_RESULTS))

print(results)
# Out:
# HTTP Request: POST http://127.0.0.1:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:6333/collections/pdf_library/points/search "HTTP/1.1 200 OK"
# 1. [0.699] David Ortolà – Control y flexibilidad en la música para piano y electrónica.pages
#    Pagina 19/26
#    File: David Ortola/David Ortola - Control y flexibilidad en la musica para piano y electronica.pages (313)/David Ortola - Control y flexibilidad en l - David Ortola.pdf
#    7. Apéndices.
# 7.1. Andrea Valle (*1974), Orologio da Rote (2014).
# En línea con la obra de Valle, haciendo uso de instrumentos controlados por medio de
# software diseñado mediante SuperCollider, esta obra-objeto inspirada en los sonetos de
# Ciro da Pers sobre «los relojes como imágenes del paso del t...
#
# 2. [0.663] UNIVERSITÀ DEGLI STUDI DI TORINO
#    Pagina 1/388
#    File: Utente della copia di valutazione di Office 2004/steffenattoZaffiri (932)/steffenattoZaffiri - Utente della copia di valutazione di Offic.pdf
#    UNIVERSITÀ DEGLI STUDI DI TORINO
# FACOLTÀ DI SCIENZE DELLA FORMAZIONE
#
#
#
# CORSO DI LAUREA SPECIALISTICA IN
# STORIA E CRITICA DELLE CULTURE E DEI BENI MUSICALI
#
#
#
# DISSERTAZIONE FINALE
#
#
# ENORE MARIA ZAFFIRI
# OLTRE MEZZO SECOLO DI ESPLORAZIONE SONORA,
# FRA RIGORE STRUTTURALISTA E LIBERA CREAT...
#
# 3. [0.629] Ministero dell’Universit`a e della Ricerca
#    Pagina 1/105
#    File: Unknown/TESI PANARIELLO ME II (316)/TESI PANARIELLO ME II - Unknown.pdf
#    3
# VA L L E : R U M E N TA R I U M
# AU TO E D U L E
# Ricercatore di cinema, fotograﬁa e televisione all’Universit`a di Torino,
# bassista elettrico interessato al rock sperimentale e al free jazz, composito-
# re e programmatore, Andrea Valle `e una ﬁgura poliedrica la cui ricerca sia
# elettroacustica che s...
#
# 4. [0.596] Ministero dell’Universit`a e della Ricerca
#    Pagina 102/105
#    File: Unknown/TESI PANARIELLO ME II (316)/TESI PANARIELLO ME II - Unknown.pdf
#    96
# bibliografia
# [14]
# T. Gorelli. I Regnum di Andrea Valle e Mauro Lanza. 2015. url: https:
# //www.thenewnoise.it/i- regnum- di- andrea- valle- e- mauro-
# lanza/.
# [15]
# S. H. Kaisler e G. Madey. Complex Adaptive Systems: Emergence and
# Self-Organization. 2009. url: https://www3.nd.edu/~gmadey/Activities/...
#
# 5. [0.593] LG_Tesi_Bozza6
#    Pagina 297/333
#    File: Luca Guidarini/LG_Tesi_Bozza6 (1177)/LG_Tesi_Bozza6 - Luca Guidarini.pdf
#    288
#
# Figura 7.12 – MAURO LANZA e ANDREA VALLE, Regnum Vegetabile, Disia belga, partitura
# strumentale, pp. 77-80.
#
#
# Figura 7.13 – MAURO LANZA e ANDREA VALLE, Regnum Vegetabile, Disia belga, partitura degli
# strumenti elettromeccanici., p. 81....

# %% [markdown]
# ## Search Anna's Archive

# %%
SEARCH_TERM = 'spectral music composition'
LIMIT = 3

try:
    results = server.search_annas_archive(SEARCH_TERM, limit=LIMIT)
except TypeError:
    import asyncio
    results = asyncio.run(server.search_annas_archive(SEARCH_TERM, limit=LIMIT))

print(results)

# %% [markdown]
# ## Download from Anna's Archive
# Paste the MD5 hash from the search results above.

# %%
MD5_HASH = ''  # <-- paste hash here e.g. 'c17f7a3108c48634ff635f34497c977b'

try:
    result = server.download_from_annas_archive(MD5_HASH)
except TypeError:
    import asyncio
    result = asyncio.run(server.download_from_annas_archive(MD5_HASH))

print(result)
